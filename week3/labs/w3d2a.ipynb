# %% [markdown]
# ![Reminder to Save](https://github.com/jamcoders/jamcoders-public-2023/blob/main/images/warning.png?raw=true)

# %%
# Always run this code.
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
  # !pip install --force-reinstall git+https://github.com/jamcoders/jamcoders-public-2023.git --quiet
  # !pip install sympy
  # !pip install numpy
import sympy
from sympy import Symbol, Function, log, sympify
from jamcoders.base_utils import *
from jamcoders.week3.labw3d2a import *
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # Week 3, Day 2, Lab A
#
# Over the past couple of weeks, we've written several functions that perform various tasks. These functions or procedures are called **algorithms**. For any algorithm that you will write, you should hope to have the following guarantees:
# * **Correctness**- The algorithm should fulfill its intended purpose
# * **Efficiency**- The algorithm should be *fast* and use as little memory as possible
#
# When we start to reason about the speed (or running time) of our algorithm, we are in the realm of **time complexity**. This lab should help you to become more confortable with this concept.

# %% [markdown]
# ## Problem 1
# When we are analyzing the time complexity of an algorithm, we care about **how the running time depends on the size of the input**. In the examples that follow, we'll typically let $n$ represent the input size and let $t(n)$ represent the running time.
#
# #### Big-O notation
# Suppose we know that a few lines of code take time $t(n)$ to be executed, and we want to find the order of $t(n)$ in Big-O notation.
#
# The goal is to simplify the expression as much as possible without changing its asymptotic growth rate. Here is a rule-of-thumb for doing that. Repeatedly perform any of the following operations in any order, until you get the simplest expression possible:
#
# 1. Regular arithmetic manipulations, such as $(3n+1)(n + 2) = 3n^2 + 7n + 2$.
#
# 2. Replace multiplicative or additive constants (i.e., a number that is not a variable, and is not in an exponent), with the number 1. For example, $3n^2 + 7n + 2 ~\rightsquigarrow~ n^2 + n + 1$. (The arrow '$\rightsquigarrow$' denotes that the expression on the right is a simplified approximation of the expression on the left.)
#
# 3. Delete any constant exponents that appear inside logarithms. For example $\log(n^2) ~\rightsquigarrow~ \log(n)$.
#
# 4. If there is a sum in which one of the terms is strictly smaller than any of the others, simply delete the smaller term. For this matter, assume that variables like $n$ are as large as we like, and in particular larger than any constant. For example, we can simplify $2\log(n) + 1000 ~\rightsquigarrow~ 2\log(n)$, because $2\log(n) > 1000$ for $n$ large enough. Generally, we have the following inequalities for $n$ large enough:
# $$
#   ~
#   \\
#   ~
# \operatorname{const} < \operatorname{const}\cdot\log(n)  < \operatorname{const}\cdot n < \operatorname{const}\cdot n \log (n) < \operatorname{const}\cdot n^2 < \operatorname{const}\cdot n^2\log(n) <~ ...,
#   ~
#   \\
#   ~
# $$
# where '$\operatorname{const}$' can be any constant numbers.
#
# Here is a complete example. We simplify the expression $t(n) = (n+3)^2 + 4(n + \log(5n^3))$. The numbers above the arrows indicate which of the operations 1 to 4 we used in each step:
#
# $$
#   ~
#   \\
#   ~
#   t(n) = (n+3)^2 + 4(n + \log(5n^3))
#   \\
#   ~
#   \\
#   ~~~~~\stackrel{(2)}{\rightsquigarrow}~
#   (n+1)^2 + (n + \log(n^3))
#   \\
#   ~
#   \\
#   ~~\stackrel{(1)}{\rightsquigarrow}~
#   n^2 + 3n + \log(n^3) + 1
#     \\
#   ~
#   \\
#   ~~\stackrel{(3)}{\rightsquigarrow}~
#   n^2 + 3n + \log(n) + 1
#    \\
#   ~
#   \\
#   ~\stackrel{(4)}{\rightsquigarrow}~
#   n^2.
#   \\
# $$
#
# Conclusion: $t(n) = O(n^2)$.

# %% [markdown]
# Once we know the Big-O order of the runtime, we have a pretty good idea of how fast the program will run for large inputs:
#
# ![image.png](data:image/png;base64,...)
#
# $\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad\qquad$<sub><sup>Image source: [bigocheatsheet.com](https://www.bigocheatsheet.com/)<sup><sub>

# %% [markdown]
# Now, let's try doing this ourselves! For each of the expressions below, provide the big-Oh notation.

# %% [markdown]
# ### 1.0 Example
# $t(n) = 2 n + 6n \log(n) + 5$

# %%
n = Symbol('n')
O = Function('O')

t = 2*n + 6*n*log(n) + 5
answer = O(n*log(n))

check_answer1_0(answer)

# %% [markdown]
# ### 1.1
# $t(n) = 10000$

# %%
n = Symbol('n')
O = Function('O')

t = 1000
answer = # YOUR ANSWER HERE

check_answer1_1(answer)

# %% [markdown]
# ### 1.2
# $t(n) = 3n + 4$

# %%
n = Symbol('n')
O = Function('O')

t = 3*n + 4
answer = # YOUR ANSWER HERE

check_answer1_2(answer)

# %% [markdown]
# ### 1.3
# $t(n) = 7n^2 + 100 n $

# %%
n = Symbol('n')
O = Function('O')

t = 7*n**2 + 100*n
answer = # YOUR ANSWER HERE

check_answer1_3(answer)

# %% [markdown]
# ### 1.4
# $t(n) = 13n + 12 n \log(n)$

# %%
n = Symbol('n')
O = Function('O')

t = 13*n + 12*n*log(n)
answer = # YOUR ANSWER HERE

check_answer1_4(answer)

# %% [markdown]
# ### 1.5
# $t(n) = 6n^3 + 13n^3 \log(n) + 8 n^2 + 9 n + 10000$

# %%
n = Symbol('n')
O = Function('O')

t = 6*n**3 + (13*n**3)*log(n) + 8*n**2 + 9*n + 10000
answer = # YOUR ANSWER HERE

check_answer1_5(answer)

# %% [markdown]
# ### 1.6
# $t(n) = 1 + 2 + 3 + \dots + n $
#
# *This problem might be more difficult than the others. Don't be afraid to ask for help!*

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer1_6(answer)

# %% [markdown]
# ### 1.7
# $t(n) = n^2 +  (\log n)^2$

# %%
n = Symbol('n')
O = Function('O')

t = n**2 + (log(n))**2
answer = # YOUR ANSWER HERE

check_answer1_7(answer)

# %% [markdown]
# 1.8
# $t(n) = n/100 +  (\log (n^{100}))^{100}$
#
# *This problem might be more difficult than the others. Don't be afraid to ask for help!*

# %%
n = Symbol('n')
O = Function('O')

t = n/100 + (log(n**(100)))**(100)
answer = # YOUR ANSWER HERE

check_answer1_8(answer)

# %% [markdown]
# ## Problem 2
#
# In this problem, you will see several pieces of code that will depend on the variables `n`. For each snippet, give  the *running time* using **big-O notation**. Please simplify your answer as much as possible.
#
# (*You can assume that any line containing math operations and assignment of variables takes 1 unit of time*.)

# %% [markdown]
# #### Example
# ```python
# b = 0                       # 1 unit
#
# for i in range(n):          # Steps below are repeated n times
#     b += 1                      # 1 unit
#     b *= 2                      # 1 unit
#     b %= 100                    # 1 unit
# ```

# %%
n = Symbol('n')
O = Function('O')

answer = O(n)

check_answer2_0(answer)

# %% [markdown]
# Here's why we said our answer is $O(n)$.
#  * The first line of code is just assigning variables, which takes constant time, which is $O(1)$.
#  * In each iteration of the loop we are updating the variable `b` using basic math operations, which takes time $O(1)$. There are $n$ iterations, so the loop takes a total time of $n \times O(1) = O(n)$.
#
# Putting it all together, the code takes time $O(1) + O(n) = O(n+1) = O(n)$.

# %% [markdown]
# ### 2.1
# ```python
# a = 0
# b = 10
# a = b + 5
# b += 10
# ```

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer2_1(answer)

# %% [markdown]
# ### 2.2
# ```python
# a = 0
#
# for i in range(n):
#     a = a / 2
#     a = a * 3
#     a = a % 100
# ```

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer2_2(answer)

# %% [markdown]
# ### 2.3
#
# ```python
# b = 0
#
# for i in range(n // 2):
#     if i % 2 == 0:
#         b = b + 2
#     else:
#         b = b * 5
#     b = b % 1000
#
# ```

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer2_3(answer)

# %% [markdown]
# ### 2.4
# ```python
# c = 0
#
# for i in range(n):
#     for j in range(n // 2):
#         c += (i * j)
#
# for i in range(n):
#     c += i
#
# ```

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer2_4(answer)

# %% [markdown]
# ### 2.5
# ```python
# b = 0
#
# for i in range(n):
#     for j in range(n):
#         for k in range(n):
#             b = (2 + j) % k
# ```

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer2_5(answer)

# %% [markdown]
# ### 2.6
# ```python
# d = 0
# c = 2
#
# for i in range(n):
#     for j in range(i):
#         d += 1
#         c = 3
# ```
#
# *This problem might be more difficult than the others. Don't be afraid to ask for help!*

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer2_6(answer)

# %% [markdown]
# ### 2.7
# ```python
# x = n
# while x > 1:
#     a = 2
#     b = a + 2
#
#     x //= 2
# ```
#
# *This problem might be more difficult than the others. Don't be afraid to ask for help!*

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer2_7(answer)

# %% [markdown]
# ### 2.8
# ```python
# a = 12
# b = 13
#
# for i in range(n):
#     for j in range(100):
#         a = b + 5
#         b = 10
#
#     for i in range(int(log(n))):
#         a += 2
# ```
#
# *This problem might be more difficult than the others. Don't be afraid to ask for help!*

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer2_8(answer)

# %% [markdown]
# ## Problem 3
# Emaan and Zaria were asked to write a function that sorts a list of items. Emaan wrote a function with a running time of $O(n^2)$. Zaria, on the other hand, wrote a function with a running time of $O(n \log (n))$. In both cases, $n$ denotes the length of the list.

# %% [markdown]
# ### 3.1
# Whose code has the better running time, in terms of Big-O?

# %%
ta = # YOUR ANSWER HERE

# %% [markdown]
# ### 3.2
# It turns out that the running time of Emaan's function is $t(n) = 0.0001 n^2$ and the running time of Zaria's function is $t(n) = 10 n \log (n)$. Give a value of $n$ that will make Emaan's function run faster than Zaria's. Assume Zaria's $\log$ is base $2$.

# %%
n = # YOUR ANSWER HERE

# %%
check_answer3(ta, n)

# %% [markdown]
# ## Problem 4
#
# Micah and Orr are having a discussion about the Big-Oh notation
#
# ### 4.1
# Consider the function $t(n) = \log(n^2)$.
# Micah is telling Orr "What are you thinking biggo? It's obvious that $t(n)$ is biggo of $\log n$ (i.e. $t(n) = O (\log n)$)". Is Micah correct? *Write your answer as a comment*.

# %%
#

# %% [markdown]
# ### 4.2
#
# Orr says he can answer Question 4.1 **without** using rule 3 (from the four simplification rules mentioned in Question 1). What explanation could he give? *Write your answer as a comment*.

# %%
#

# %% [markdown]
# ### 4.3
# Consider the function $t(n) = \log (n^n)$.
# Now, Micah is trying to convince Orr that $t(n) = O(\log n)$. Is Micah correct? Explain your answer **without** using rule 3. *Write your answer as a comment*.

# %%
#

# %% [markdown]
# ## 5 Binary Search and Cake Order Hackers
#
# Sugar & Spice receive thousands of cake orders per day. Each order is assigned an order number, such as `1569`. Orders are stored in a sorted list called `orders`. For example, `orders = [1343, 28343, 32450]`.
#
# To find out the details for a given order number, they use the `details` list, indexed with the index of the order number `details[order_num_idx]`. For example, if they had 3 orders, their `orders` and `details` lists might look something like this:
#
# `orders = [327, 2878, 19999]`
# `details = ['Simple cake', 'Write: Happy Birthday Biggo', 'N/A']`
#
# Some hacked into the Sugar & Spice database and replaced all the orders with nonsense, except for order number `77224`. Fill in the following code for `binary_search_orders` to find the index corresponding to the order number, and print the message the hackers left.
#
# _Hint:_ this is very similar to previous binary search questions, except in the end, you want to print the message using the index of the order number that you found.

# %%
import numpy as np
np.random.seed(0)
num_orders = 10000
orders = sorted(np.random.randint(100000, size=num_orders))
details = ["Sorry, this is not the right order, there must be a bug in your code 👀"] * 10000
details[np.random.randint(num_orders)] = "~Congrats! This is the right order! Give us $1m and we'll restore your database. Follow instructions here: https://www.youtube.com/watch?v=dQw4w9WgXcQ ~"

# %%
def binary_search_orders(orders, order_num):
    left = 0 # DO NOT CHANGE THIS LINE
    right = len(orders) - 1 # DO NOT CHANGE THIS LINE

    while
        mid = (left + right) // 2
        if orders[mid] < order_num:
            # FILL THIS IN
        elif # FILL THIS IN
            # FILL THIS IN
        else:
            # FILL THIS IN
    return -1


# Test your code with the following, you should see a special message (rather than a "Sorry ..." message).
idx = binary_search_orders(orders, 77224)
print(f"I think the order number 77224 is at index {idx}.")
print(f"Here is the order number at idx {idx}: {orders[idx]}.")
print(f"This is the message:", details[idx])

# %% [markdown]
# ## 6 Challenge Problem
#
# ```python
# x = n
# out = 0
#
# while x != 1:
#     for i in range(x):
#         out += 1
#     x //= 2
# ```

# %%
n = Symbol('n')
O = Function('O')

answer = # YOUR ANSWER HERE

check_answer5_1(answer)
