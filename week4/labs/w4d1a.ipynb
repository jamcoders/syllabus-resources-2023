# %% [markdown]
# ![Reminder to Save](https://github.com/jamcoders/jamcoders-public-2023/blob/main/images/warning.png?raw=true)

# %%
# Always run this code.
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # !pip install --force-reinstall git+https://github.com/jamcoders/jamcoders-public-2023.git --quiet 
from jamcoders.base_utils import *
from jamcoders.week4.labw4d1a import *

# %% [markdown]
# # Week 2 Day 5 (Lecture 10) Exercises
# ## 1. Dictionary Review
#
# A dictionary or `dict` in Python is a object that stores a "value" at every "key".
#
# In an English dictionary, like the Oxford English dictionary, the key is the word and the value is the definition. Run the code to create the dictionary. Read through the code, and try understand how it works.

# %%
oxford_english_dictionary = {
    'computer': 'an electronic machine that can store, organize and find information, do processes with numbers and other data, and control other machines',

    'mango': 'a tropical fruit with smooth yellow or red skin, that is soft and orange inside with a large seed',

    'python': 'a large tropical snake that kills animals for food by winding its long body tightly around them',

}

# %% [markdown]
# Unlike the real Oxford English dictionary, it doesn't matter what order the entries come in. Run the code below to see:

# %%
oxford_english_dictionary_backwards = {
    'python': 'a large tropical snake that kills animals for food by winding its long body tightly around them',

    'mango': 'a tropical fruit with smooth yellow or red skin, that is soft and orange inside with a large seed',

    'computer': 'an electronic machine that can store, organize and find information, do processes with numbers and other data, and control other machines',
}

print(oxford_english_dictionary == oxford_english_dictionary_backwards)

# %% [markdown]
# Given a **dictionary**, we can **retrieve the value** corresponding to a given **key** using **square bracket notation** (similar to list indexing). Run the code below to see how to access the dictionary.
#
# Read through the code and try to understand how it works. Change things around in this cell and the previous cell and see if it does what you want it to.

# %%
mango_definition = oxford_english_dictionary['mango']
print(mango_definition)

# %% [markdown]
# Micah is trying to remember the capital city of each country. He wrote the dictionary below to map country names (the keys) to the names of their capitals (the values).
#
# Run the code below to create the dictionary:

# %%
country_to_capital = {
    'Jamaica': 'Kingston',
    'Canada': 'Toronto',
    'Australia': 'Sydney',
    'Turkey': 'Ankara'
}

# print it to see what is inside
print(country_to_capital)

# %% [markdown]
# Note that it doesn't matter if all the dictionary entries are on the same line or if some are on new lines - as long as they
# - start with `{`
# - end with `}`
# - and are separated by commas.
#
# Try running the code below:

# %%
country_to_capital = {'Jamaica': 'Kingston', 'Canada': 'Toronto', 'Australia': 'Sydney', 'Turkey': 'Ankara'}

# print it to see what is inside
print(country_to_capital)

# %% [markdown]
# ### 1.1 What would Python do?
# Without running any code, write down what value you think would be printed for each line. If you think there would be an error, write 'error'
#
# ```python
# #1a
# print(country_to_capital['Canada'])
# #1b
# print(country_to_capital['Turkey'])
# #1c
# print(country_to_capital['USA'])
# #1d
# print(country_to_capital['Kingston']
# ```

# %%
answer_1a = ...
answer_1b = ...
answer_1c = ...
answer_1d = ...

check_answer_1a(answer_1a)
check_answer_1b(answer_1b)
check_answer_1c(answer_1c)
check_answer_1d(answer_1d)

# %% [markdown]
# If there were any answers that were 'error', explain below why there would be an error:

# %%
# Answer here

# %% [markdown]
# ### 1.2 Changing Dictionaries
# Oops- Micah made a mistake. The capital of Australia is not Sydney, it's actually Canberra. The value for any key in a dictionary can be changed. Run the code below to try it:

# %%
country_to_capital['Australia'] = 'Canberra'
print(country_to_capital['Australia'])

# %% [markdown]
# Micah made another mistake- the capital of Canada is not Toronto, it's Ottowa. Now, write code to change the `country_to_capital` dictionary to fix the mistake. Feel free at any point to try different things and see what works.

# %%
# your code here

assert_equal(got=country_to_capital['Canada'],want='Ottowa')

# %% [markdown]
# Micah just learnt that the capital of Germany is Berlin. **Adding new items to the dictionary** is the same as changing an existing item. Read through this code to understand, and then run it.

# %%
country_to_capital['Germany'] = 'Berlin'
print(country_to_capital['Germany'])

# %% [markdown]
# Now help Micah out by adding one more country and capital to the dictionary:

# %%
# your code here

assert_equal(got=len(country_to_capital), want=6)
assert_equal("dict", type(country_to_capital).__name__)

# %% [markdown]
# There are also a few useful ways to get a list of a dictionary's **keys, a list of its values, or to check the number of entries**.
#
# Sidenote: Some of the below code may be new to you. For example, the use of `list()` may be new. Python uses `list(input)` to convert other objects into lists.
#
# Read through the code and try to understand how it works.

# %%
print("The list of keys:")
key_list = list(country_to_capital.keys())
print(key_list)  # Countries.

print("")
print("The list of values:")
value_list = list(country_to_capital.values())
print(value_list)  # Their capitals.

print("")
print("The dictionary length:")
dictionary_length = len(country_to_capital)
print(dictionary_length)  # Number of countries the dictionary contains.

# %% [markdown]
# You can also check **if a *key* exists in the dictionary** using the `in` operator. This only checks for the keys, not the values! This returns a **boolean (i.e., True or False)**.

# %%
print('Jamaica' in country_to_capital)
print('Kingston' in country_to_capital)

# %% [markdown]
# ### 1.3 What would Python do?
#
# Below is a dictionary, `users`, that maps a person's username to their formal name. What would the following lines of code print? If there would be an error, write 'error'.

# %% [markdown]
# ```python
# users = {
#     'bereket2002': 'Bereket Molla',
#     'minilek': 'Jelani Nelson',
#     'tyler_is_cool': 'Tyler Hou',
# }
#
# #1.3a
# print(len(users))
# #1.3b
# print("minilek" in users)
# #1.3c
# print("chronixx" in users)
# #1.3d
# print("Tyler Hou" in users)
# #1.3e
# print(users[0])
# #1.3f
# users2 = {'tyler_is_cool':'Tyler Hou', 'bereket2002':'Bereket Molla', 'minilek':'Jelani Nelson'}
# print(users2==users)
# #1.3g
# users3 = {'Bereket Molla':'bereket2002', 'Jelani Nelson':'minilek', 'Tyler Hou':'tyler_is_cool'}
# print(users3==users)
# #1.3h
# print('Jelani Nelson' in list(users.values()))
# ```

# %%
answer_1_3a = ...
answer_1_3b = ...
answer_1_3c = ...
answer_1_3d = ...
answer_1_3e = ...
answer_1_3f = ...
answer_1_3g = ...
answer_1_3h = ...

check_answer_1_3([answer_1_3a,answer_1_3b,answer_1_3c,answer_1_3d,answer_1_3e,answer_1_3f, answer_1_3g, answer_1_3h])

# %% [markdown]
# If any of the answers was 'error', explain why below. We encourage you to ask a TA for guidance if you feel unsure.

# %%
# explanation here

# %% [markdown]
# ### 1.4 Empty Dictionaries
#
# Create an empty dictionary. In other words, create a dictionary that has no keys or values in it.

# %%
empty_dict = # your code here

assert_equal("dict", type(empty_dict).__name__)
assert_equal(0, len(empty_dict))

# %% [markdown]
# ## 2. My friends, and I

# %% [markdown]
# ### 2.1 `friends`
#
# Write a dictionary `my_friends` mapping the names of five of your friends to their ages (don't worry about being accurate). In other words, we want a dictionary with peoples' names as keys, and their ages as values.

# %%
my_friends = # your code here

assert_equal("dict", type(my_friends).__name__)
assert_equal(5, len(my_friends))

# %% [markdown]
# ### 2.2 `add_friend`

# %% [markdown]
# Now, write a function `add_friend(d, name, age)` that adds a new friend with name `name` and age `age` to the dictionary `d` of friends.
#
# Don't return anything- just change the dictonary `d` inside the function by adding this new key-value pair!

# %%
def add_friend(d, name, age):
    """Records your new friend's name and age in the dictionary `d`.

    Args:
        d (dict(str: int)): The dictionary that maps your friends' names to their ages.
        name (str): Your new friend's name.
        age (int): Your new friend's age.

    Returns: None.
    """
    # Your code here.


# Checking your code - don't change this
test_friends = {"Barney": 500, "Cailou": 4, "Lala": 2, "Blue": 19, "Jimmy Newtron": 14}
assert_equal(None, add_friend(test_friends, 'Damerae', 19))
assert_equal(19, test_friends['Damerae'])

# %% [markdown]
# ### 2.3 The potion of youth
#
# You and your friends have discovered a magic potion that makes the drinker 2 years younger. Write a function `drink_magic_potion` that takes your friend's name and updates their age in the dictionary to be two years younger. This function should not return anything- it just changes the dictionary.

# %%
def drink_magic_potion(d, name):
    """Change dictionary `d` to decrease the age of the person with the specified name by 2 years.
    
    Args:
        d (dict(str: int)): The dictionary that maps your friends' names to their ages.
        name (string): The potion drinker's name.

    Returns: None.
    """
    # Your code here.



# Checking your code - don't change this
test_friends = {"Barney": 500, "Cailou": 4, "Lala": 2, "Blue": 19, "Jimmy Newtron": 14}
assert_equal(None, drink_magic_potion(test_friends, "Barney"))
assert_equal(498, test_friends["Barney"])
drink_magic_potion(test_friends, "Cailou")
assert_equal(2, test_friends["Cailou"])

# %% [markdown]
# ### 2.4 `average_friends_age`
#
# Write a function `average_friends_age` that takes a dictionary `d`. `d` maps the names of friends to their ages. `average_friends_age` should return the average age of all the friends in the dictionary.
#
# Hint: use `list(d.values())` to get all the ages as a list!

# %%
def average_friends_age(d):
    """Computes the average age of friends in the given dictionary.

    Args:
        d (dict(str: int)): The dictionary that maps your friends' names to their ages.

    Returns (float): The average age of all friends.
    """
    # Your code here.


# Checking your code - don't change this
test_friends = {"Barney": 500, "Cailou": 4, "Lala": 2, "Blue": 19, "Jimmy Newtron": 14}
assert_equal(107.8, average_friends_age(test_friends))

test_friends2 = {"Barney": 100, "Cailou": 4}
assert_equal(52, average_friends_age(test_friends2))

# %% [markdown]
# ## 3. Trivia!
#
# Let's use dictionaries to make a trivia game! Here is how you can get input from the player, try this out:

# %%
user_input = input("Enter whatever text you like here -> ")
print("The user just entered this text: " + user_input)

# %% [markdown]
# *Note that if you enter a number in the input box, it will still be treated as a string!*
#
# Now, use this to make a trivia game.
#
# 1. Store a bunch of trivia questions and answers as a dictionary `questions_to_answers`
#
# 2. Create a variable to keep track of how many questions the player got correct.
#
# 3. Loop through all the questions and ask them to the player. For each question, let the player `input` their answer. Check if the answer is correct, and tell them if they got it right. If they were wrong, tell them the correct answer. Update the player's score.
#
# 4. Once all the questions are done, tell the player how many questions they got correct out of how many total questions
#
# When your code is working, let the students sitting next to you play your trivia game!

# %%
# Customize this message to welcome the user to your trivia game:
print("Let's play trivia!")

# 1. put some trivia questions and answers into a dictionary
questions_to_answers = ...


# Code for steps 2 and 3 here:


# 4. Finally print out the total number of questions the player got correct, out of how many questions total:
print(None)

# %% [markdown]
# ## 4. Counting birds
#
# Brenda the birdwatcher hates counting, so whenever she sees a bird she just writes down its name. Now she has a list of bird species:
# ```python
# birds_seen = ['sparrow','pigeon','crow','pigeon','crow','crow','owl']
# ```
# ### 4.1
# A common use for dictionaries is to help us count how many times we have seen something.
# Write a function `get_counts(names)` that generates a dictionary mapping each name in  `names` to the count of how many times it appeared in the list. For example:
#
# ```python
# get_counts(birds_seen)
# ```
# should return
# ```python
# {
#     'sparrow': 1,
#     'pigeon': 2,
#     'crow': 3,
#     'owl': 1
# }
# ```

# %%
def get_counts(names):
    """Counts how many times each name appears in names

    Args:
        names (list[str]): The input list of all the names.
    
    Returns: 
        (dict(str: int)): A dictionary that maps each name to the number of times it appears
    """
    # Your code here.


#Checking your code (don't change this)
birds_seen = ['sparrow','pigeon','crow','pigeon','crow','crow','owl']
bird_counts = get_counts(birds_seen)
assert_equal(want={'sparrow': 1,'pigeon': 2, 'crow': 3,'owl': 1}, got=bird_counts)

birds_seen2 = ['hawk','robin','pigeon','robin']
bird_counts2 = get_counts(birds_seen2)
assert_equal(want={'hawk': 1,'robin': 2, 'pigeon': 1}, got=bird_counts2)

# %% [markdown]
# ### 4.2
#
# Brenda hasn't seen any other birds, so for example `counts['eagle']` should be 0. Write a function `get_item_count(counts, item)` that returns the current count of an item, and if an item is not in the dictionary, it returns `0`.

# %%
def get_item_count(counter, item):
    """Retrieves the current item's count from the counter.
    If we have not seen the item so far, returns 0.
    
    Args:
        counter (dict(str: int)): The counter dictionary
        item (str): The item whose count we are retrieving.
        
    Returns (int): The item's current count. If not seen, 0.
    """
    # Your code here.


# Checking your code (don't change this)
assert_equal(0, get_item_count(bird_counts, 'robin'))
assert_equal(1, get_item_count(bird_counts, 'sparrow'))
assert_equal(0, get_item_count(bird_counts, 'eagle'))
assert_equal(3, get_item_count(bird_counts, 'crow'))

# %% [markdown]
# ### 4.3
# Now write a function that uses the `bird_counts` dictionary to tell us how many different species of bird Brenda saw (don't overthink it!)

# %%
def get_num_species(counts_dict):
    """Tells us how many different species of bird Brenda saw
    
    Args:
        counts_dict (dict(str: int)): The counter dictionary
        
    Returns (int): The number of unique bird species seen.
    """
    # Your code here.


# Checking your code (don't change this)
print('Test Cases: ')
num_species = get_num_species(bird_counts)
assert_equal(got=get_num_species(bird_counts), want=4)
test_counts = {"shrimp": 87, "shark": 4, "whale": 2, "dolphin": 19, "jellyfish": 14}
assert_equal(got=get_num_species(test_counts), want=5)

# %% [markdown]
# ## 5. Dictionaries at the Cafe

# %% [markdown]
# ### 5.1
# Zaria buys some drinks for her friends on the way to class. Micah and Kerene both asked for a latte, Alok wants a smoothie, Pawat requested a lemonade, and Ian wants a tea. First run this code below to create the drink menu dictionary:

# %%
drink_menu = {
    'latte': 500,
    'mocha': 600,
    'tea': 400,
    'smoothie': 550,
    'lemonade': 450,

}

# %% [markdown]
# Make a dictionary `drink_orders` to keep track of who ordered what drink:

# %%
drink_orders = # your code here


# Checking your code (don't change this)
assert_equal('latte', drink_orders['Micah'])
assert_equal('latte', drink_orders['Kerene'])
assert_equal('tea', drink_orders['Ian'])
assert_equal(5, len(drink_orders))

# %% [markdown]
# Why would it be a bad idea to have the keys be the drinks and the values be the names of Zaria's friends?

# %%
# your answer here

# %% [markdown]
# ### 5.2
# Now, write a function `get_total_cost` that returns the total cost of the drinks.

# %%
def get_total_cost(orders, menu):
    """Use the menu to get the total cost of all the orders.
    Args:
        orders (dict(str: str)): Dictionary mapping the person's name to the drink that they ordered
        menu (dict(str: int)): Dictionary mapping the drink name to how much it costs
    Returns:
        (int): the total cost of all the drinks
    """
    # your code here

# Checking your code (don't change this)
assert_equal(2400, get_total_cost(drink_orders, drink_menu))
assert_equal(0, get_total_cost({}, drink_menu))
assert_equal(500, get_total_cost({'Orr':'latte'}, drink_menu))

# %% [markdown]
# ### 5.3 Items
# When processing dictionaries, instead of going through all the dictionary keys and looking up the values, it can be easier to just go through the dictionary items. Run the code to see how dictionary items work:

# %%
for item in drink_menu.items():
    print(item)

# %% [markdown]
# There is a neat way to access the keys and values while going through the dctionary:

# %%
for drink_name, menu_price in drink_menu.items():
    print("drink: ", drink_name)
    print ("price: ", menu_price)

# %% [markdown]
# Now use `.items()` to write a function to *return a dictionary* that tells Zaria how much each friend owes her. So the keys should be the names of her friends and the values should be the amount of money they owe. Can you write this function in only 5 lines, including the `def` and `return` lines?

# %%
def get_owed # your code here


# Test cases- don't change any code below this line!
owed = get_owed(drink_orders, drink_menu)

assert_equal(500, owed['Micah'])
assert_equal(500, owed['Kerene'])
assert_equal(400, owed['Ian'])
assert_equal(5, len(owed))

#another test case
owed2 = get_owed({'Li':'latte','Micah':'tea'}, drink_menu)
assert_equal(500, owed2['Li'])
assert_equal(400, owed2['Micah'])

# %% [markdown]
# # 6. Dividing students into groups
#
# We are given a list of strings `names` that contains the names of students in a classroom. The teacher of the class wants to group the students by the first letter of their names.
#
# ### 6.1
# First, for each letter we want you to count the number of students whose names start with that letter.
# Write a function `get_first_letter_counts` for this problem.
#
# Example:
# ```python
# get_first_letter_counts(['Daniel', 'Basi', 'Bereket', 'Dim', 'Leello'])
# ```
# should return
# ```python
# {'B': 2, 'D': 2, 'L': 1}
#  ```

# %%
def get_first_letter_counts(names):
    """finds the number of names starting with each letter

    Args:
        names (list(str)): The input list of all the names.
    
    Returns: 
        (dict(str: int)): A dictionary that maps letters to the number of names starting with that letter.
    """
    # Your code here.


# checking your code (don't change this)
names = ['Daniel', 'Basi', 'Bereket', 'Dim', 'Leello']
assert_equal(get_first_letter_counts(names), {'B': 2, 'D': 2, 'L': 1})
names2 = ['Jon', 'Kerene', 'Jonathan', 'Zaria', 'Koda', 'Jennie']
assert_equal(get_first_letter_counts(names2), {'J': 3, 'Z': 1, 'K': 2})

# %% [markdown]
# ### 6.2 dictionaries with list values!
#
# Now write a function called `group_by_first_letter` to create the actual student groupings.
#
# For example,
# ```python
# group_by_first_letter(['Daniel', 'Basi', 'Bereket', 'Dim', 'Leello'])
# ```
# should return
# ```python
# {'B': ['Basi', 'Bereket'],  'D': ['Daniel', 'Dim'], 'L': ['Leello']}
# ```
#
# Hint: you should use the `append` function to add an item to a list!

# %%
def group_by_first_letter(names):
    """Groups students by the first letter of their name.
    Args:
        names (list(str)): The input list of all the names.

    Returns: (dict(str: list(str)): A dictionary that maps letters to lists of names starting with that letter.
    """
    # Your code here.



# checking your code (don't change this)
names = ['Daniel', 'Basi', 'Bereket', 'Dim', 'Leello']
student_groups = group_by_first_letter(names)
assert_equal(want={'B': ['Basi', 'Bereket'], 'D': ['Daniel', 'Dim'],'L': ['Leello']}, got = student_groups)

names2 = ['Jon', 'Kerene', 'Jonathan', 'Koda', 'Jennie']
student_groups2 = group_by_first_letter(names2)
assert_equal(want = {'J': ['Jon', 'Jonathan', 'Jennie'], 'K': ['Kerene', 'Koda']}, got = student_groups2)

# %% [markdown]
# ### 6.3
# Now the teacher wants to assign a leader for each group, and decides the leader should be the student with the longest name. Write a function `pick_leaders` to pick the student from each group with the longest name and return a dictionary of the group leaders. For example,
# ```python
# pick_leaders(student_groups)
# ```
# should return
# ```python
# {'B':'Bereket', 'D':'Daniel', 'L':'Leello'}
# ```
#
# Hint: you might want to use a `for` loop nested inside another `for` loop

# %%
def pick_leaders(groups):
    """Gets a dictionary of group leaders by choosing the person with the longest name from each group.
    
    Args:
        groups (dict(str: list(str))): The dictionary containing the groups.
        
    Returns (dict(str: str)): A dictionary of just the group leaders.
    """
    # Your code here.

leaders = pick_leaders(student_groups)
assert_equal(want={'B':'Bereket', 'D':'Daniel', 'L':'Leello'}, got=leaders)
leaders2 = pick_leaders(student_groups2)
assert_equal(want={'J': 'Jonathan', 'K': 'Kerene'}, got=leaders2)
